# %%
import numpy as np
import healpy as hp
#import ConfigParser
from astropy.io import fits as pyfits
import matplotlib.pyplot as plt
import sys

# %%
map_Dwingeloo = pyfits.getdata("CHIPASS_Gal_compact.fits")
map_Dwingeloo.shape
hp.mollview(map_Dwingeloo, cmap='jet', title='CHIPASS_Gal_compact')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-d9ae53a637ca> in <module>
#       1 map_Dwingeloo = pyfits.getdata("CHIPASS_Gal_compact.fits")
#       2 map_Dwingeloo.shape
# ----> 3 hp.mollview(map_Dwingeloo, cmap='jet', title='CHIPASS_Gal_compact')
#
# ~/.local/lib/python3.8/site-packages/healpy/visufunc.py in mollview(map, fig, rot, coord, unit, xsize, title, nest, min, max, flip, remove_dip, remove_mono, gal_cut, format, format2, cbar, cmap, badcolor, bgcolor, notext, norm, hold, margins, sub, nlocs, return_projected_map)
#     180
#     181     # Ensure that the nside is valid
# --> 182     nside = pixelfunc.get_nside(map)
#     183     pixelfunc.check_nside(nside, nest=nest)
#     184
#
# ~/.local/lib/python3.8/site-packages/healpy/pixelfunc.py in get_nside(m)
#    1798     a TypeError exception is raised.
#    1799     """
# -> 1800     typ = maptype(m)
# ...

# %%
stars = (map_Dwingeloo >0)
hp.mollview(stars)
hp.write_map('map_Dwingeloo_mask.fits', stars)

# %%
sync = pyfits.getdata("Commander_step1_synch.fits")
hp.mollview(sync[15,:])
sync.shape
# Out:
# /home/karin/.local/lib/python3.8/site-packages/healpy/projaxes.py:907: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   newcm.set_over(newcm(1.0))
# /home/karin/.local/lib/python3.8/site-packages/healpy/projaxes.py:908: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   newcm.set_under(bgcolor)
# ...

# %%
teste = (sync[15,:])*stars
hp.mollview(teste, min=0, max=10000)
